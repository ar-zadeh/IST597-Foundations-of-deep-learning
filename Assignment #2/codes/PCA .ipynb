# %%
""" 
author:-aam35

"""
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import numpy as np
import tensorflow as tf
tf.enable_eager_execution()
import time
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import tensorflow.contrib.eager as tfe
from sklearn.decomposition import PCA




tf.executing_eagerly()
# Define paramaters for the model
learning_rate = 0.001
batch_size = 200
n_epochs = 200
n_train = 55000
n_test = 10000

# %%
from tensorflow.examples.tutorials.mnist import input_data
train, val, test = input_data.read_data_sets('data/fashion', source_url='http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/',one_hot=True,)
# Out:
# WARNING:tensorflow:From <ipython-input-2-0b106b6b18aa>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 26421880 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 29515 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 4422102 bytes.
# Extracting data/fashion/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 5148 bytes.
# Extracting data/fashion/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X =np.append(train.images,test.images,axis=0)

# %%
pca = PCA(0.99)

# %%
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.99, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
w = tf.Variable(tf.random_normal([pca.transform(train.images).shape[1],train.labels.shape[1]],stddev=0.01))
b = tf.Variable(tf.zeros([1 , train.labels.shape[1]],dtype=tf.float32))

# %%
def model(x):
  U1 = (((np.random.rand(img.shape[0]*img.shape[1]))>0.0).reshape(img.shape)/1).astype('float32')
  r =tf.convert_to_tensor (x *U1)
  logits = tf.matmul(r,w) + b
  return logits

# %%
def prediction(x):
  pred = tf.matmul(x,w) + b
  return pred

# %%
#evaluate the loss

variables=[w,b]
def loss(model, img, label):
  prediction = model(img)
  return tf.losses.softmax_cross_entropy(label, logits=prediction)

#record the gradient with respect to the model variables 
def grad(model, img, label):
  with tf.GradientTape() as tape:
    loss_value = loss(model, img, label)
  return tape.gradient(loss_value, variables)

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
n_batch=train.images.shape[0]//batch_size

# %%
for i in range(n_epochs):
  for j in range(n_batch):
    img , label=train.next_batch(batch_size= batch_size)
    img = pca.transform(img)
    grads=grad(model,img,label)
    optimizer.apply_gradients(zip(grads,variables),global_step=tf.train.get_or_create_global_step())
  #train acc
  input_data = pca.transform(train.images)
  label_value=train.labels
  preds = tf.nn.softmax(prediction(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'training accuracy after {i+1} epochs is {accuracy}')
  #test acc
  input_data = pca.transform(test.images)
  label_value=test.labels
  preds = tf.nn.softmax(prediction(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'test accuracy after {i+1} epochs is {accuracy}')
# Out:
# training accuracy after 0 epochs is 0.8099818229675293
# test accuracy after 1 epochs is 0.8019999861717224
# training accuracy after 1 epochs is 0.8323636651039124
# test accuracy after 2 epochs is 0.8223999738693237
# training accuracy after 2 epochs is 0.8434363603591919
# test accuracy after 3 epochs is 0.8284000158309937
# training accuracy after 3 epochs is 0.848800003528595
# test accuracy after 4 epochs is 0.8327000141143799
# training accuracy after 4 epochs is 0.852581799030304
# test accuracy after 5 epochs is 0.8353999853134155
# training accuracy after 5 epochs is 0.8555818200111389
# test accuracy after 6 epochs is 0.8356999754905701
# training accuracy after 6 epochs is 0.858018159866333
# test accuracy after 7 epochs is 0.8367999792098999
# training accuracy after 7 epochs is 0.8603272438049316
# test accuracy after 8 epochs is 0.8382999897003174
# training accuracy after 8 epochs is 0.8612727522850037
# test accuracy after 9 epochs is 0.8389000296592712
# training accuracy after 9 epochs is 0.8628727197647095
# test accuracy after 10 epochs is 0.838699996471405
# training accuracy after 10 epochs is 0.8633999824523926
# test accuracy after 11 epochs is 0.8392999768257141
# training accuracy after 11 epochs is 0.8644909262657166
# test accuracy after 12 epochs is 0.8398000001907349
# training accuracy after 12 epochs is 0.8648181557655334
# test accuracy after 13 epochs is 0.8393999934196472
# training accuracy after 13 epochs is 0.8657272458076477
# test accuracy after 14 epochs is 0.8391000032424927
# training accuracy after 14 epochs is 0.8660181760787964
# test accuracy after 15 epochs is 0.8403000235557556
# training accuracy after 15 epochs is 0.8669454455375671
# test accuracy after 16 epochs is 0.8411999940872192
# training accuracy after 16 epochs is 0.8671091198921204
# test accuracy after 17 epochs is 0.8396000266075134
# training accuracy after 17 epochs is 0.8674908876419067
# test accuracy after 18 epochs is 0.8411999940872192
# training accuracy after 18 epochs is 0.8682000041007996
# test accuracy after 19 epochs is 0.8409000039100647
# training accuracy after 19 epochs is 0.8682727217674255
# test accuracy after 20 epochs is 0.8416000008583069
# training accuracy after 20 epochs is 0.8685636520385742
# test accuracy after 21 epochs is 0.8416000008583069
# training accuracy after 21 epochs is 0.8682363629341125
# test accuracy after 22 epochs is 0.8420000076293945
# training accuracy after 22 epochs is 0.8685818314552307
# test accuracy after 23 epochs is 0.8413000106811523
# training accuracy after 23 epochs is 0.8689454793930054
# test accuracy after 24 epochs is 0.8414999842643738
# training accuracy after 24 epochs is 0.8696727156639099
# test accuracy after 25 epochs is 0.8417999744415283
# training accuracy after 25 epochs is 0.8699454665184021
# test accuracy after 26 epochs is 0.842199981212616
# training accuracy after 26 epochs is 0.8695818185806274
# test accuracy after 27 epochs is 0.8417999744415283
# training accuracy after 27 epochs is 0.8698363900184631
# test accuracy after 28 epochs is 0.8411999940872192
# training accuracy after 28 epochs is 0.8701090812683105
# test accuracy after 29 epochs is 0.8416000008583069
# training accuracy after 29 epochs is 0.8706908822059631
# test accuracy after 30 epochs is 0.8424000144004822
# training accuracy after 30 epochs is 0.8705272674560547
# test accuracy after 31 epochs is 0.8418999910354614
# training accuracy after 31 epochs is 0.8708363771438599
# test accuracy after 32 epochs is 0.8424000144004822
# training accuracy after 32 epochs is 0.8709090948104858
# test accuracy after 33 epochs is 0.8420000076293945
# training accuracy after 33 epochs is 0.8717454671859741
# test accuracy after 34 epochs is 0.84170001745224
# training accuracy after 34 epochs is 0.8713091015815735
# test accuracy after 35 epochs is 0.8424999713897705
# training accuracy after 35 epochs is 0.8716909289360046
# test accuracy after 36 epochs is 0.8407999873161316
# training accuracy after 36 epochs is 0.8717272877693176
# test accuracy after 37 epochs is 0.8420000076293945
# training accuracy after 37 epochs is 0.8715090751647949
# test accuracy after 38 epochs is 0.8410999774932861
# training accuracy after 38 epochs is 0.871963620185852
# test accuracy after 39 epochs is 0.84170001745224
# training accuracy after 39 epochs is 0.8716909289360046
# test accuracy after 40 epochs is 0.8411999940872192
# training accuracy after 40 epochs is 0.8720909357070923
# test accuracy after 41 epochs is 0.8406999707221985
# training accuracy after 41 epochs is 0.872036337852478
# test accuracy after 42 epochs is 0.8409000039100647
# training accuracy after 42 epochs is 0.8719817996025085
# test accuracy after 43 epochs is 0.840499997138977
# training accuracy after 43 epochs is 0.8722545504570007
# test accuracy after 44 epochs is 0.8411999940872192
# training accuracy after 44 epochs is 0.8721454739570618
# test accuracy after 45 epochs is 0.8418999910354614
# training accuracy after 45 epochs is 0.8720727562904358
# test accuracy after 46 epochs is 0.8410000205039978
# training accuracy after 46 epochs is 0.8725273013114929
# test accuracy after 47 epochs is 0.8406999707221985
# training accuracy after 47 epochs is 0.8724181652069092
# test accuracy after 48 epochs is 0.8421000242233276
# training accuracy after 48 epochs is 0.8722181916236877
# test accuracy after 49 epochs is 0.8414000272750854
# training accuracy after 49 epochs is 0.871999979019165
# test accuracy after 50 epochs is 0.8413000106811523
# training accuracy after 50 epochs is 0.8726909160614014
# test accuracy after 51 epochs is 0.8406000137329102
# training accuracy after 51 epochs is 0.8723454475402832
# test accuracy after 52 epochs is 0.8411999940872192
# training accuracy after 52 epochs is 0.8722545504570007
# test accuracy after 53 epochs is 0.8406000137329102
# training accuracy after 53 epochs is 0.8725636601448059
# test accuracy after 54 epochs is 0.8416000008583069
# training accuracy after 54 epochs is 0.87298184633255
# test accuracy after 55 epochs is 0.8410000205039978
# training accuracy after 55 epochs is 0.8727636337280273
# test accuracy after 56 epochs is 0.840499997138977
# training accuracy after 56 epochs is 0.8727454543113708
# test accuracy after 57 epochs is 0.8410999774932861
# training accuracy after 57 epochs is 0.8729272484779358
# test accuracy after 58 epochs is 0.8411999940872192
# training accuracy after 58 epochs is 0.8727454543113708
# test accuracy after 59 epochs is 0.8407999873161316
# training accuracy after 59 epochs is 0.8726545572280884
# test accuracy after 60 epochs is 0.8407999873161316
# training accuracy after 60 epochs is 0.8728908896446228
# test accuracy after 61 epochs is 0.8414999842643738
# training accuracy after 61 epochs is 0.8731818199157715
# test accuracy after 62 epochs is 0.8396000266075134
# training accuracy after 62 epochs is 0.8726545572280884
# test accuracy after 63 epochs is 0.8409000039100647
# training accuracy after 63 epochs is 0.8728545308113098
# test accuracy after 64 epochs is 0.8406000137329102
# training accuracy after 64 epochs is 0.8727818131446838
# test accuracy after 65 epochs is 0.8413000106811523
# training accuracy after 65 epochs is 0.8725636601448059
# test accuracy after 66 epochs is 0.8411999940872192
# training accuracy after 66 epochs is 0.8733817934989929
# test accuracy after 67 epochs is 0.8406999707221985
# training accuracy after 67 epochs is 0.8731818199157715
# test accuracy after 68 epochs is 0.8414999842643738
# training accuracy after 68 epochs is 0.8733454346656799
# test accuracy after 69 epochs is 0.8413000106811523
# training accuracy after 69 epochs is 0.8731818199157715
# test accuracy after 70 epochs is 0.8410000205039978
# training accuracy after 70 epochs is 0.8737090826034546
# test accuracy after 71 epochs is 0.840499997138977
# training accuracy after 71 epochs is 0.8735091090202332
# test accuracy after 72 epochs is 0.8417999744415283
# training accuracy after 72 epochs is 0.8731818199157715
# test accuracy after 73 epochs is 0.8421000242233276
# training accuracy after 73 epochs is 0.8732908964157104
# test accuracy after 74 epochs is 0.8414999842643738
# training accuracy after 74 epochs is 0.8735272884368896
# test accuracy after 75 epochs is 0.8407999873161316
# training accuracy after 75 epochs is 0.8740363717079163
# test accuracy after 76 epochs is 0.8407999873161316
# training accuracy after 76 epochs is 0.8732181787490845
# test accuracy after 77 epochs is 0.840399980545044
# training accuracy after 77 epochs is 0.8742727041244507
# test accuracy after 78 epochs is 0.8407999873161316
# training accuracy after 78 epochs is 0.8736000061035156
# test accuracy after 79 epochs is 0.8413000106811523
# training accuracy after 79 epochs is 0.8737818002700806
# test accuracy after 80 epochs is 0.8420000076293945
# training accuracy after 80 epochs is 0.8736545443534851
# test accuracy after 81 epochs is 0.8410999774932861
# training accuracy after 81 epochs is 0.8736727237701416
# test accuracy after 82 epochs is 0.8406999707221985
# training accuracy after 82 epochs is 0.8736545443534851
# test accuracy after 83 epochs is 0.8406000137329102
# training accuracy after 83 epochs is 0.8737272620201111
# test accuracy after 84 epochs is 0.8409000039100647
# training accuracy after 84 epochs is 0.8739272952079773
# test accuracy after 85 epochs is 0.8410000205039978
# training accuracy after 85 epochs is 0.8739454746246338
# test accuracy after 86 epochs is 0.8406999707221985
# training accuracy after 86 epochs is 0.8734727501869202
# test accuracy after 87 epochs is 0.8418999910354614
# training accuracy after 87 epochs is 0.8743273019790649
# test accuracy after 88 epochs is 0.8410999774932861
# training accuracy after 88 epochs is 0.8741272687911987
# test accuracy after 89 epochs is 0.8406999707221985
# training accuracy after 89 epochs is 0.8737454414367676
# test accuracy after 90 epochs is 0.8410000205039978
# training accuracy after 90 epochs is 0.8738727569580078
# test accuracy after 91 epochs is 0.8402000069618225
# training accuracy after 91 epochs is 0.8737454414367676
# test accuracy after 92 epochs is 0.8406999707221985
# training accuracy after 92 epochs is 0.8738545179367065
# test accuracy after 93 epochs is 0.8418999910354614
# training accuracy after 93 epochs is 0.8740363717079163
# test accuracy after 94 epochs is 0.8407999873161316
# training accuracy after 94 epochs is 0.8738545179367065
# test accuracy after 95 epochs is 0.8410000205039978
# training accuracy after 95 epochs is 0.8741999864578247
# test accuracy after 96 epochs is 0.8400999903678894
# training accuracy after 96 epochs is 0.8738181591033936
# test accuracy after 97 epochs is 0.8414999842643738
# training accuracy after 97 epochs is 0.8737818002700806
# test accuracy after 98 epochs is 0.8410000205039978
# training accuracy after 98 epochs is 0.8736909031867981
# test accuracy after 99 epochs is 0.8406000137329102
# training accuracy after 99 epochs is 0.8740000128746033
# test accuracy after 100 epochs is 0.8402000069618225
# training accuracy after 100 epochs is 0.8741272687911987
# test accuracy after 101 epochs is 0.8414000272750854
# training accuracy after 101 epochs is 0.8743818402290344
# test accuracy after 102 epochs is 0.8402000069618225
# training accuracy after 102 epochs is 0.8737272620201111
# test accuracy after 103 epochs is 0.8407999873161316
# training accuracy after 103 epochs is 0.8743454813957214
# test accuracy after 104 epochs is 0.8403000235557556
# training accuracy after 104 epochs is 0.8740545511245728
# test accuracy after 105 epochs is 0.840399980545044
# training accuracy after 105 epochs is 0.8743818402290344
# test accuracy after 106 epochs is 0.839900016784668
# training accuracy after 106 epochs is 0.8741818070411682
# test accuracy after 107 epochs is 0.8406000137329102
# training accuracy after 107 epochs is 0.8741636276245117
# test accuracy after 108 epochs is 0.840399980545044
# training accuracy after 108 epochs is 0.8743818402290344
# test accuracy after 109 epochs is 0.8406000137329102
# training accuracy after 109 epochs is 0.8744000196456909
# test accuracy after 110 epochs is 0.8402000069618225
# training accuracy after 110 epochs is 0.8742181658744812
# test accuracy after 111 epochs is 0.8414999842643738
# training accuracy after 111 epochs is 0.8740181922912598
# test accuracy after 112 epochs is 0.8410999774932861
# training accuracy after 112 epochs is 0.8741454482078552
# test accuracy after 113 epochs is 0.8406999707221985
# training accuracy after 113 epochs is 0.8745636343955994
# test accuracy after 114 epochs is 0.840499997138977
# training accuracy after 114 epochs is 0.8744545578956604
# test accuracy after 115 epochs is 0.8414000272750854
# training accuracy after 115 epochs is 0.8745090961456299
# test accuracy after 116 epochs is 0.8409000039100647
# training accuracy after 116 epochs is 0.8744363784790039
# test accuracy after 117 epochs is 0.8407999873161316
# training accuracy after 117 epochs is 0.8742545247077942
# test accuracy after 118 epochs is 0.8402000069618225
# training accuracy after 118 epochs is 0.8742181658744812
# test accuracy after 119 epochs is 0.8392999768257141
# training accuracy after 119 epochs is 0.8742545247077942
# test accuracy after 120 epochs is 0.8406999707221985
# training accuracy after 120 epochs is 0.8746908903121948
# test accuracy after 121 epochs is 0.8410000205039978
# training accuracy after 121 epochs is 0.8746181726455688
# test accuracy after 122 epochs is 0.8403000235557556
# training accuracy after 122 epochs is 0.8746545314788818
# test accuracy after 123 epochs is 0.8410000205039978
# training accuracy after 123 epochs is 0.8744000196456909
# test accuracy after 124 epochs is 0.8410000205039978
# training accuracy after 124 epochs is 0.8743818402290344
# test accuracy after 125 epochs is 0.8396999835968018
# training accuracy after 125 epochs is 0.8741272687911987
# test accuracy after 126 epochs is 0.840499997138977
# training accuracy after 126 epochs is 0.8749818205833435
# test accuracy after 127 epochs is 0.8399999737739563
# training accuracy after 127 epochs is 0.8744000196456909
# test accuracy after 128 epochs is 0.84170001745224
# training accuracy after 128 epochs is 0.8743818402290344
# test accuracy after 129 epochs is 0.8410999774932861
# training accuracy after 129 epochs is 0.8749454617500305
# test accuracy after 130 epochs is 0.8403000235557556
# training accuracy after 130 epochs is 0.8743636608123779
# test accuracy after 131 epochs is 0.8392999768257141
# training accuracy after 131 epochs is 0.8747636079788208
# test accuracy after 132 epochs is 0.8409000039100647
# training accuracy after 132 epochs is 0.8746727108955383
# test accuracy after 133 epochs is 0.8417999744415283
# training accuracy after 133 epochs is 0.8747090697288513
# test accuracy after 134 epochs is 0.8398000001907349
# training accuracy after 134 epochs is 0.8750545382499695
# test accuracy after 135 epochs is 0.8403000235557556
# training accuracy after 135 epochs is 0.874890923500061
# test accuracy after 136 epochs is 0.8410999774932861
# training accuracy after 136 epochs is 0.8747636079788208
# test accuracy after 137 epochs is 0.8414000272750854
# training accuracy after 137 epochs is 0.8747818470001221
# test accuracy after 138 epochs is 0.8413000106811523
# training accuracy after 138 epochs is 0.8752363920211792
# test accuracy after 139 epochs is 0.8403000235557556
# training accuracy after 139 epochs is 0.8746545314788818
# test accuracy after 140 epochs is 0.8409000039100647
# training accuracy after 140 epochs is 0.875036358833313
# test accuracy after 141 epochs is 0.8410999774932861
# training accuracy after 141 epochs is 0.8746908903121948
# test accuracy after 142 epochs is 0.8406000137329102
# training accuracy after 142 epochs is 0.8749454617500305
# test accuracy after 143 epochs is 0.8403000235557556
# training accuracy after 143 epochs is 0.874890923500061
# test accuracy after 144 epochs is 0.8402000069618225
# training accuracy after 144 epochs is 0.8758909106254578
# test accuracy after 145 epochs is 0.8406999707221985
# training accuracy after 145 epochs is 0.8749091029167175
# test accuracy after 146 epochs is 0.8406000137329102
# training accuracy after 146 epochs is 0.8747636079788208
# test accuracy after 147 epochs is 0.8411999940872192
# training accuracy after 147 epochs is 0.8746363520622253
# test accuracy after 148 epochs is 0.8406999707221985
# training accuracy after 148 epochs is 0.8750908970832825
# test accuracy after 149 epochs is 0.8410000205039978
# training accuracy after 149 epochs is 0.8754909038543701
# test accuracy after 150 epochs is 0.8410999774932861
# training accuracy after 150 epochs is 0.8746545314788818
# test accuracy after 151 epochs is 0.8406999707221985
# training accuracy after 151 epochs is 0.8749454617500305
# test accuracy after 152 epochs is 0.8398000001907349
# training accuracy after 152 epochs is 0.8747454285621643
# test accuracy after 153 epochs is 0.8402000069618225
# training accuracy after 153 epochs is 0.8749091029167175
# test accuracy after 154 epochs is 0.8396999835968018
# training accuracy after 154 epochs is 0.8750908970832825
# test accuracy after 155 epochs is 0.8400999903678894
# training accuracy after 155 epochs is 0.8751636147499084
# test accuracy after 156 epochs is 0.840399980545044
# training accuracy after 156 epochs is 0.8747090697288513
# test accuracy after 157 epochs is 0.8414000272750854
# training accuracy after 157 epochs is 0.8747818470001221
# test accuracy after 158 epochs is 0.8402000069618225
# training accuracy after 158 epochs is 0.8747272491455078
# test accuracy after 159 epochs is 0.8396000266075134
# training accuracy after 159 epochs is 0.8748727440834045
# test accuracy after 160 epochs is 0.8396000266075134
# training accuracy after 160 epochs is 0.8746727108955383
# test accuracy after 161 epochs is 0.8398000001907349
# training accuracy after 161 epochs is 0.8749091029167175
# test accuracy after 162 epochs is 0.8406999707221985
# training accuracy after 162 epochs is 0.8744363784790039
# test accuracy after 163 epochs is 0.8403000235557556
# training accuracy after 163 epochs is 0.8749091029167175
# test accuracy after 164 epochs is 0.8399999737739563
# training accuracy after 164 epochs is 0.8752909302711487
# test accuracy after 165 epochs is 0.8410000205039978
# training accuracy after 165 epochs is 0.8752909302711487
# test accuracy after 166 epochs is 0.8403000235557556
# training accuracy after 166 epochs is 0.875145435333252
# test accuracy after 167 epochs is 0.839900016784668
# training accuracy after 167 epochs is 0.8746727108955383
# test accuracy after 168 epochs is 0.839900016784668
# training accuracy after 168 epochs is 0.875072717666626
# test accuracy after 169 epochs is 0.8407999873161316
# training accuracy after 169 epochs is 0.8752727508544922
# test accuracy after 170 epochs is 0.8402000069618225
# training accuracy after 170 epochs is 0.8752181529998779
# test accuracy after 171 epochs is 0.8396999835968018
# training accuracy after 171 epochs is 0.8755454421043396
# test accuracy after 172 epochs is 0.8407999873161316
# training accuracy after 172 epochs is 0.8750908970832825
# test accuracy after 173 epochs is 0.8406000137329102
# training accuracy after 173 epochs is 0.8750181794166565
# test accuracy after 174 epochs is 0.8396999835968018
# training accuracy after 174 epochs is 0.874963641166687
# test accuracy after 175 epochs is 0.8407999873161316
# training accuracy after 175 epochs is 0.8753091096878052
# test accuracy after 176 epochs is 0.839900016784668
# training accuracy after 176 epochs is 0.8753091096878052
# test accuracy after 177 epochs is 0.840399980545044
# training accuracy after 177 epochs is 0.8753818273544312
# test accuracy after 178 epochs is 0.8402000069618225
# training accuracy after 178 epochs is 0.8755454421043396
# test accuracy after 179 epochs is 0.8402000069618225
# training accuracy after 179 epochs is 0.875145435333252
# test accuracy after 180 epochs is 0.839900016784668
# training accuracy after 180 epochs is 0.875145435333252
# test accuracy after 181 epochs is 0.840399980545044
# training accuracy after 181 epochs is 0.8753454685211182
# test accuracy after 182 epochs is 0.8396999835968018
# training accuracy after 182 epochs is 0.8755636215209961
# test accuracy after 183 epochs is 0.8403000235557556
# training accuracy after 183 epochs is 0.8753454685211182
# test accuracy after 184 epochs is 0.840399980545044
# training accuracy after 184 epochs is 0.8755636215209961
# test accuracy after 185 epochs is 0.840499997138977
# training accuracy after 185 epochs is 0.8753091096878052
# test accuracy after 186 epochs is 0.839900016784668
# training accuracy after 186 epochs is 0.8754000067710876
# test accuracy after 187 epochs is 0.8398000001907349
# training accuracy after 187 epochs is 0.8758545517921448
# test accuracy after 188 epochs is 0.8406000137329102
# training accuracy after 188 epochs is 0.8754545450210571
# test accuracy after 189 epochs is 0.8396999835968018
# training accuracy after 189 epochs is 0.8753818273544312
# test accuracy after 190 epochs is 0.839900016784668
# training accuracy after 190 epochs is 0.8751817941665649
# test accuracy after 191 epochs is 0.8407999873161316
# training accuracy after 191 epochs is 0.8753272891044617
# test accuracy after 192 epochs is 0.8402000069618225
# training accuracy after 192 epochs is 0.8759090900421143
# test accuracy after 193 epochs is 0.8400999903678894
# training accuracy after 193 epochs is 0.8754000067710876
# test accuracy after 194 epochs is 0.840499997138977
# training accuracy after 194 epochs is 0.8758000135421753
# test accuracy after 195 epochs is 0.8395000100135803
# training accuracy after 195 epochs is 0.8750545382499695
# test accuracy after 196 epochs is 0.8399999737739563
# training accuracy after 196 epochs is 0.8753636479377747
# test accuracy after 197 epochs is 0.839900016784668
# training accuracy after 197 epochs is 0.8757636547088623
# test accuracy after 198 epochs is 0.839900016784668
# training accuracy after 198 epochs is 0.8758727312088013
# test accuracy after 199 epochs is 0.8398000001907349
# training accuracy after 199 epochs is 0.8753272891044617
# test accuracy after 200 epochs is 0.8389000296592712
