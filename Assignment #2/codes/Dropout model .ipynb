# %%
""" 
author:-aam35

"""
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import numpy as np
import tensorflow as tf
tf.enable_eager_execution()
import time
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import tensorflow.contrib.eager as tfe
from sklearn.decomposition import PCA



tf.executing_eagerly()
# Define paramaters for the model
learning_rate = 0.001
batch_size = 200
n_epochs = 200
n_train = 55000
n_test = 10000

# %%
from tensorflow.examples.tutorials.mnist import input_data
train, val, test = input_data.read_data_sets('data/fashion', source_url='http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/',one_hot=True,)
# Out:
# WARNING:tensorflow:From <ipython-input-2-0b106b6b18aa>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/fashion/t10k-images-idx3-ubyte.gz
# Extracting data/fashion/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
img, label = train.next_batch(batch_size)

# %%
w = tf.Variable(tf.random_normal([train.images.shape[1],train.labels.shape[1]],stddev=0.01))
b = tf.Variable(tf.zeros([1 , train.labels.shape[1]],dtype=tf.float32))

# %%
def model(x):
  U1 = (((np.random.rand(img.shape[0]*img.shape[1]))>0.3).reshape(200,784)/0.7).astype('float32')
  r =tf.convert_to_tensor (x *U1)
  logits = tf.matmul(r,w) + b
  return logits

# %%
def prediction(x):
  pred = tf.matmul(x,w) + b
  return pred

# %%
#evaluate the loss

variables=[w,b]
def loss(model, img, label):
  prediction = model(img)
  return tf.losses.softmax_cross_entropy(label, logits=prediction)

#record the gradient with respect to the model variables 
def grad(model, img, label):
  with tf.GradientTape() as tape:
    loss_value = loss(model, img, label)
  return tape.gradient(loss_value, variables)

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
n_batch=train.images.shape[0]//batch_size

# %%
for i in range(n_epochs):
  for j in range(n_batch):
    img , label=train.next_batch(batch_size= batch_size)
    img = img/255
    grads=grad(model,img,label)
    optimizer.apply_gradients(zip(grads,variables),global_step=tf.train.get_or_create_global_step())
  #train acc
  input_data = train.images/255
  label_value=train.labels
  preds = tf.nn.softmax(prediction(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'training accuracy after {i} epochs is {accuracy}')
  #test acc
  input_data = test.images/255
  label_value=test.labels
  preds = tf.nn.softmax(prediction(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'test accuracy after {i+1} epochs is {accuracy}')
# Out:
# training accuracy after 0 epochs is 0.8076000213623047
# test accuracy after 1 epochs is 0.7990000247955322
# training accuracy after 1 epochs is 0.8077818155288696
# test accuracy after 2 epochs is 0.8001999855041504
# training accuracy after 2 epochs is 0.8072909116744995
# test accuracy after 3 epochs is 0.8001000285148621
# training accuracy after 3 epochs is 0.8081818222999573
# test accuracy after 4 epochs is 0.7994999885559082
# training accuracy after 4 epochs is 0.8083999752998352
# test accuracy after 5 epochs is 0.8008999824523926
# training accuracy after 5 epochs is 0.808509111404419
# test accuracy after 6 epochs is 0.8001999855041504
# training accuracy after 6 epochs is 0.8080363869667053
# test accuracy after 7 epochs is 0.8008999824523926
# training accuracy after 7 epochs is 0.8086000084877014
# test accuracy after 8 epochs is 0.8003000020980835
# training accuracy after 8 epochs is 0.8089636564254761
# test accuracy after 9 epochs is 0.8014000058174133
# training accuracy after 9 epochs is 0.8090181946754456
# test accuracy after 10 epochs is 0.8011999726295471
# training accuracy after 10 epochs is 0.8092363476753235
# test accuracy after 11 epochs is 0.8015000224113464
# training accuracy after 11 epochs is 0.809145450592041
# test accuracy after 12 epochs is 0.801800012588501
# training accuracy after 12 epochs is 0.8096727132797241
# test accuracy after 13 epochs is 0.8008999824523926
# training accuracy after 13 epochs is 0.80925452709198
# test accuracy after 14 epochs is 0.8021000027656555
# training accuracy after 14 epochs is 0.8091636300086975
# test accuracy after 15 epochs is 0.802299976348877
# training accuracy after 15 epochs is 0.8106908798217773
# test accuracy after 16 epochs is 0.8012999892234802
# training accuracy after 16 epochs is 0.8099272847175598
# test accuracy after 17 epochs is 0.8015999794006348
# training accuracy after 17 epochs is 0.8103272914886475
# test accuracy after 18 epochs is 0.8019000291824341
# training accuracy after 18 epochs is 0.8104000091552734
# test accuracy after 19 epochs is 0.8030999898910522
# training accuracy after 19 epochs is 0.8101454377174377
# test accuracy after 20 epochs is 0.8032000064849854
# training accuracy after 20 epochs is 0.8106363415718079
# test accuracy after 21 epochs is 0.8022000193595886
# training accuracy after 21 epochs is 0.810945451259613
# test accuracy after 22 epochs is 0.802299976348877
# training accuracy after 22 epochs is 0.8111818432807922
# test accuracy after 23 epochs is 0.8026999831199646
# training accuracy after 23 epochs is 0.8114181756973267
# test accuracy after 24 epochs is 0.8025000095367432
# training accuracy after 24 epochs is 0.8113090991973877
# test accuracy after 25 epochs is 0.803600013256073
# training accuracy after 25 epochs is 0.8115817904472351
# test accuracy after 26 epochs is 0.8030999898910522
# training accuracy after 26 epochs is 0.8119817972183228
# test accuracy after 27 epochs is 0.8033999800682068
# training accuracy after 27 epochs is 0.8121272921562195
# test accuracy after 28 epochs is 0.8029000163078308
# training accuracy after 28 epochs is 0.8126545548439026
# test accuracy after 29 epochs is 0.8029999732971191
# training accuracy after 29 epochs is 0.8122909069061279
# test accuracy after 30 epochs is 0.8039000034332275
# training accuracy after 30 epochs is 0.8123090863227844
# test accuracy after 31 epochs is 0.8033999800682068
# training accuracy after 31 epochs is 0.8129818439483643
# test accuracy after 32 epochs is 0.8039000034332275
# training accuracy after 32 epochs is 0.8126181960105896
# test accuracy after 33 epochs is 0.8027999997138977
# training accuracy after 33 epochs is 0.8130182027816772
# test accuracy after 34 epochs is 0.8033999800682068
# training accuracy after 34 epochs is 0.8137272596359253
# test accuracy after 35 epochs is 0.8029000163078308
# training accuracy after 35 epochs is 0.8131818175315857
# test accuracy after 36 epochs is 0.8034999966621399
# training accuracy after 36 epochs is 0.8136363625526428
# test accuracy after 37 epochs is 0.8039000034332275
# training accuracy after 37 epochs is 0.813909113407135
# test accuracy after 38 epochs is 0.804099977016449
# training accuracy after 38 epochs is 0.8138181567192078
# test accuracy after 39 epochs is 0.8034999966621399
# training accuracy after 39 epochs is 0.8143272995948792
# test accuracy after 40 epochs is 0.8043000102043152
# training accuracy after 40 epochs is 0.8143091201782227
# test accuracy after 41 epochs is 0.8034999966621399
# training accuracy after 41 epochs is 0.8145272731781006
# test accuracy after 42 epochs is 0.8044000267982483
# training accuracy after 42 epochs is 0.8144545555114746
# test accuracy after 43 epochs is 0.8050000071525574
# training accuracy after 43 epochs is 0.8148000240325928
# test accuracy after 44 epochs is 0.8050000071525574
# training accuracy after 44 epochs is 0.8148545622825623
# test accuracy after 45 epochs is 0.8044000267982483
# training accuracy after 45 epochs is 0.8150363564491272
# test accuracy after 46 epochs is 0.8054999709129333
# training accuracy after 46 epochs is 0.8148727416992188
# test accuracy after 47 epochs is 0.8051999807357788
# training accuracy after 47 epochs is 0.8148363828659058
# test accuracy after 48 epochs is 0.805899977684021
# training accuracy after 48 epochs is 0.8155454397201538
# test accuracy after 49 epochs is 0.805400013923645
# training accuracy after 49 epochs is 0.8154545426368713
# test accuracy after 50 epochs is 0.8048999905586243
# training accuracy after 50 epochs is 0.815818190574646
# test accuracy after 51 epochs is 0.8058000206947327
# training accuracy after 51 epochs is 0.8162181973457336
# test accuracy after 52 epochs is 0.8065000176429749
# training accuracy after 52 epochs is 0.8153272867202759
# test accuracy after 53 epochs is 0.8062000274658203
# training accuracy after 53 epochs is 0.8161454796791077
# test accuracy after 54 epochs is 0.805899977684021
# training accuracy after 54 epochs is 0.8162181973457336
# test accuracy after 55 epochs is 0.8068000078201294
# training accuracy after 55 epochs is 0.8167636394500732
# test accuracy after 56 epochs is 0.8066999912261963
# training accuracy after 56 epochs is 0.8163272738456726
# test accuracy after 57 epochs is 0.8062000274658203
# training accuracy after 57 epochs is 0.8166909217834473
# test accuracy after 58 epochs is 0.8065999746322632
# training accuracy after 58 epochs is 0.8168181777000427
# test accuracy after 59 epochs is 0.8075000047683716
# training accuracy after 59 epochs is 0.8169999718666077
# test accuracy after 60 epochs is 0.8068000078201294
# training accuracy after 60 epochs is 0.8172727227210999
# test accuracy after 61 epochs is 0.8076000213623047
# training accuracy after 61 epochs is 0.8166909217834473
# test accuracy after 62 epochs is 0.8065999746322632
# training accuracy after 62 epochs is 0.817509114742279
# test accuracy after 63 epochs is 0.8082000017166138
# training accuracy after 63 epochs is 0.817545473575592
# test accuracy after 64 epochs is 0.8076000213623047
# training accuracy after 64 epochs is 0.817545473575592
# test accuracy after 65 epochs is 0.807699978351593
# training accuracy after 65 epochs is 0.81776362657547
# test accuracy after 66 epochs is 0.8083000183105469
# training accuracy after 66 epochs is 0.8178908824920654
# test accuracy after 67 epochs is 0.8076000213623047
# training accuracy after 67 epochs is 0.8177454471588135
# test accuracy after 68 epochs is 0.8080000281333923
# training accuracy after 68 epochs is 0.8188727498054504
# test accuracy after 69 epochs is 0.808899998664856
# training accuracy after 69 epochs is 0.8183272480964661
# test accuracy after 70 epochs is 0.8083999752998352
# training accuracy after 70 epochs is 0.8183272480964661
# test accuracy after 71 epochs is 0.8084999918937683
# training accuracy after 71 epochs is 0.8184000253677368
# test accuracy after 72 epochs is 0.8084999918937683
# training accuracy after 72 epochs is 0.818818211555481
# test accuracy after 73 epochs is 0.8087999820709229
# training accuracy after 73 epochs is 0.8187636137008667
# test accuracy after 74 epochs is 0.808899998664856
# training accuracy after 74 epochs is 0.8191999793052673
# test accuracy after 75 epochs is 0.8091999888420105
# training accuracy after 75 epochs is 0.8190545439720154
# test accuracy after 76 epochs is 0.808899998664856
# training accuracy after 76 epochs is 0.8192727565765381
# test accuracy after 77 epochs is 0.8093000054359436
# training accuracy after 77 epochs is 0.8192363381385803
# test accuracy after 78 epochs is 0.8095999956130981
# training accuracy after 78 epochs is 0.819381833076477
# test accuracy after 79 epochs is 0.8090999722480774
# training accuracy after 79 epochs is 0.819527268409729
# test accuracy after 80 epochs is 0.809499979019165
# training accuracy after 80 epochs is 0.819709062576294
# test accuracy after 81 epochs is 0.8097000122070312
# training accuracy after 81 epochs is 0.819672703742981
# test accuracy after 82 epochs is 0.8095999956130981
# training accuracy after 82 epochs is 0.8199272751808167
# test accuracy after 83 epochs is 0.8100000023841858
# training accuracy after 83 epochs is 0.8200363516807556
# test accuracy after 84 epochs is 0.8095999956130981
# training accuracy after 84 epochs is 0.8198000192642212
# test accuracy after 85 epochs is 0.8098999857902527
# training accuracy after 85 epochs is 0.8200727105140686
# test accuracy after 86 epochs is 0.8101999759674072
# training accuracy after 86 epochs is 0.8203272819519043
# test accuracy after 87 epochs is 0.8090999722480774
# training accuracy after 87 epochs is 0.8205636143684387
# test accuracy after 88 epochs is 0.8104000091552734
# training accuracy after 88 epochs is 0.8201636075973511
# test accuracy after 89 epochs is 0.8105000257492065
# training accuracy after 89 epochs is 0.8204181790351868
# test accuracy after 90 epochs is 0.810699999332428
# training accuracy after 90 epochs is 0.8206363916397095
# test accuracy after 91 epochs is 0.810699999332428
# training accuracy after 91 epochs is 0.8208727240562439
# test accuracy after 92 epochs is 0.8102999925613403
# training accuracy after 92 epochs is 0.8209818005561829
# test accuracy after 93 epochs is 0.8111000061035156
# training accuracy after 93 epochs is 0.8209454417228699
# test accuracy after 94 epochs is 0.8112000226974487
# training accuracy after 94 epochs is 0.8210909366607666
# test accuracy after 95 epochs is 0.8113999962806702
# training accuracy after 95 epochs is 0.8211818337440491
# test accuracy after 96 epochs is 0.8116000294685364
# training accuracy after 96 epochs is 0.8212000131607056
# test accuracy after 97 epochs is 0.8112000226974487
# training accuracy after 97 epochs is 0.8215454816818237
# test accuracy after 98 epochs is 0.8119000196456909
# training accuracy after 98 epochs is 0.8217818140983582
# test accuracy after 99 epochs is 0.8116000294685364
# training accuracy after 99 epochs is 0.8216181993484497
# test accuracy after 100 epochs is 0.8118000030517578
# training accuracy after 100 epochs is 0.8220000267028809
# test accuracy after 101 epochs is 0.8125
# training accuracy after 101 epochs is 0.8217999935150146
# test accuracy after 102 epochs is 0.8116999864578247
# training accuracy after 102 epochs is 0.8220363855361938
# test accuracy after 103 epochs is 0.8123999834060669
# training accuracy after 103 epochs is 0.8220182061195374
# test accuracy after 104 epochs is 0.8119000196456909
# training accuracy after 104 epochs is 0.82143634557724
# test accuracy after 105 epochs is 0.8123999834060669
# training accuracy after 105 epochs is 0.8220909237861633
# test accuracy after 106 epochs is 0.8119000196456909
# training accuracy after 106 epochs is 0.8221272826194763
# test accuracy after 107 epochs is 0.8126000165939331
# training accuracy after 107 epochs is 0.8224727511405945
# test accuracy after 108 epochs is 0.8125
# training accuracy after 108 epochs is 0.8223272562026978
# test accuracy after 109 epochs is 0.8123999834060669
# training accuracy after 109 epochs is 0.8223454356193542
# test accuracy after 110 epochs is 0.8126999735832214
# training accuracy after 110 epochs is 0.8223817944526672
# test accuracy after 111 epochs is 0.8122000098228455
# training accuracy after 111 epochs is 0.8229636549949646
# test accuracy after 112 epochs is 0.8126000165939331
# training accuracy after 112 epochs is 0.8228726983070374
# test accuracy after 113 epochs is 0.8123999834060669
# training accuracy after 113 epochs is 0.8227999806404114
# test accuracy after 114 epochs is 0.8133000135421753
# training accuracy after 114 epochs is 0.8229818344116211
# test accuracy after 115 epochs is 0.8130000233650208
# training accuracy after 115 epochs is 0.8228545188903809
# test accuracy after 116 epochs is 0.8125
# training accuracy after 116 epochs is 0.8230727314949036
# test accuracy after 117 epochs is 0.8123000264167786
# training accuracy after 117 epochs is 0.823272705078125
# test accuracy after 118 epochs is 0.8127999901771545
# training accuracy after 118 epochs is 0.8230000138282776
# test accuracy after 119 epochs is 0.8133999705314636
# training accuracy after 119 epochs is 0.8235999941825867
# test accuracy after 120 epochs is 0.8125
# training accuracy after 120 epochs is 0.8237090706825256
# test accuracy after 121 epochs is 0.8129000067710876
# training accuracy after 121 epochs is 0.8233454823493958
# test accuracy after 122 epochs is 0.8127999901771545
# training accuracy after 122 epochs is 0.8239272832870483
# test accuracy after 123 epochs is 0.8127999901771545
# training accuracy after 123 epochs is 0.8234363794326782
# test accuracy after 124 epochs is 0.8131999969482422
# training accuracy after 124 epochs is 0.8238545656204224
# test accuracy after 125 epochs is 0.8129000067710876
# training accuracy after 125 epochs is 0.8237818479537964
# test accuracy after 126 epochs is 0.8130999803543091
# training accuracy after 126 epochs is 0.8239091038703918
# test accuracy after 127 epochs is 0.8127999901771545
# training accuracy after 127 epochs is 0.8235090970993042
# test accuracy after 128 epochs is 0.8137000203132629
# training accuracy after 128 epochs is 0.824363648891449
# test accuracy after 129 epochs is 0.8130999803543091
# training accuracy after 129 epochs is 0.8241454362869263
# test accuracy after 130 epochs is 0.8126999735832214
# training accuracy after 130 epochs is 0.824290931224823
# test accuracy after 131 epochs is 0.8137999773025513
# training accuracy after 131 epochs is 0.8241999745368958
# test accuracy after 132 epochs is 0.8133000135421753
# training accuracy after 132 epochs is 0.824436366558075
# test accuracy after 133 epochs is 0.8130000233650208
# training accuracy after 133 epochs is 0.8240727186203003
# test accuracy after 134 epochs is 0.8137000203132629
# training accuracy after 134 epochs is 0.8244727253913879
# test accuracy after 135 epochs is 0.8138999938964844
# training accuracy after 135 epochs is 0.8248909115791321
# test accuracy after 136 epochs is 0.8134999871253967
# training accuracy after 136 epochs is 0.8245090842247009
# test accuracy after 137 epochs is 0.8134999871253967
# training accuracy after 137 epochs is 0.8247272968292236
# test accuracy after 138 epochs is 0.8134999871253967
# training accuracy after 138 epochs is 0.8248727321624756
# test accuracy after 139 epochs is 0.8133000135421753
# training accuracy after 139 epochs is 0.8243454694747925
# test accuracy after 140 epochs is 0.8136000037193298
# training accuracy after 140 epochs is 0.824436366558075
# test accuracy after 141 epochs is 0.8140000104904175
# training accuracy after 141 epochs is 0.8246545195579529
# test accuracy after 142 epochs is 0.8136000037193298
# training accuracy after 142 epochs is 0.82510906457901
# test accuracy after 143 epochs is 0.8134999871253967
# training accuracy after 143 epochs is 0.8248000144958496
# test accuracy after 144 epochs is 0.8141999840736389
# training accuracy after 144 epochs is 0.8249818086624146
# test accuracy after 145 epochs is 0.8137999773025513
# training accuracy after 145 epochs is 0.825036346912384
# test accuracy after 146 epochs is 0.8140000104904175
# training accuracy after 146 epochs is 0.8252727389335632
# test accuracy after 147 epochs is 0.8144000172615051
# training accuracy after 147 epochs is 0.8255090713500977
# test accuracy after 148 epochs is 0.8144000172615051
# training accuracy after 148 epochs is 0.8254181742668152
# test accuracy after 149 epochs is 0.814300000667572
# training accuracy after 149 epochs is 0.8252182006835938
# test accuracy after 150 epochs is 0.8141000270843506
# training accuracy after 150 epochs is 0.8258908987045288
# test accuracy after 151 epochs is 0.8147000074386597
# training accuracy after 151 epochs is 0.8254727125167847
# test accuracy after 152 epochs is 0.8148000240325928
# training accuracy after 152 epochs is 0.8256545662879944
# test accuracy after 153 epochs is 0.8151999711990356
# training accuracy after 153 epochs is 0.8253454566001892
# test accuracy after 154 epochs is 0.8151999711990356
# training accuracy after 154 epochs is 0.8257272839546204
# test accuracy after 155 epochs is 0.8152999877929688
# training accuracy after 155 epochs is 0.826163649559021
# test accuracy after 156 epochs is 0.814300000667572
# training accuracy after 156 epochs is 0.8258908987045288
# test accuracy after 157 epochs is 0.8144999742507935
# training accuracy after 157 epochs is 0.8254545331001282
# test accuracy after 158 epochs is 0.8148000240325928
# training accuracy after 158 epochs is 0.8257818222045898
# test accuracy after 159 epochs is 0.8152999877929688
# training accuracy after 159 epochs is 0.8262909054756165
# test accuracy after 160 epochs is 0.8155999779701233
# training accuracy after 160 epochs is 0.8263818025588989
# test accuracy after 161 epochs is 0.815500020980835
# training accuracy after 161 epochs is 0.8254908919334412
# test accuracy after 162 epochs is 0.8155999779701233
# training accuracy after 162 epochs is 0.8258908987045288
# test accuracy after 163 epochs is 0.8151000142097473
# training accuracy after 163 epochs is 0.8264363408088684
# test accuracy after 164 epochs is 0.8159999847412109
# training accuracy after 164 epochs is 0.8264181613922119
# test accuracy after 165 epochs is 0.8156999945640564
# training accuracy after 165 epochs is 0.8262181878089905
# test accuracy after 166 epochs is 0.8159999847412109
# training accuracy after 166 epochs is 0.8264545202255249
# test accuracy after 167 epochs is 0.8158000111579895
# training accuracy after 167 epochs is 0.8267636299133301
# test accuracy after 168 epochs is 0.8159000277519226
# training accuracy after 168 epochs is 0.8267454504966736
# test accuracy after 169 epochs is 0.8159999847412109
# training accuracy after 169 epochs is 0.8270363807678223
# test accuracy after 170 epochs is 0.8166000247001648
# training accuracy after 170 epochs is 0.8272181749343872
# test accuracy after 171 epochs is 0.816100001335144
# training accuracy after 171 epochs is 0.8265636563301086
# test accuracy after 172 epochs is 0.815500020980835
# training accuracy after 172 epochs is 0.8270727396011353
# test accuracy after 173 epochs is 0.8158000111579895
# training accuracy after 173 epochs is 0.8268181681632996
# test accuracy after 174 epochs is 0.8166000247001648
# training accuracy after 174 epochs is 0.8275454640388489
# test accuracy after 175 epochs is 0.8165000081062317
# training accuracy after 175 epochs is 0.8274000287055969
# test accuracy after 176 epochs is 0.8159000277519226
# training accuracy after 176 epochs is 0.8266909122467041
# test accuracy after 177 epochs is 0.8162999749183655
# training accuracy after 177 epochs is 0.8275272846221924
# test accuracy after 178 epochs is 0.8159999847412109
# training accuracy after 178 epochs is 0.8273817896842957
# test accuracy after 179 epochs is 0.8167999982833862
# training accuracy after 179 epochs is 0.8269636631011963
# test accuracy after 180 epochs is 0.8166999816894531
# training accuracy after 180 epochs is 0.8274000287055969
# test accuracy after 181 epochs is 0.8167999982833862
# training accuracy after 181 epochs is 0.8275091052055359
# test accuracy after 182 epochs is 0.8167999982833862
# training accuracy after 182 epochs is 0.8271636366844177
# test accuracy after 183 epochs is 0.8163999915122986
# training accuracy after 183 epochs is 0.8278363347053528
# test accuracy after 184 epochs is 0.8169000148773193
# training accuracy after 184 epochs is 0.8278727531433105
# test accuracy after 185 epochs is 0.8166999816894531
# training accuracy after 185 epochs is 0.8274727463722229
# test accuracy after 186 epochs is 0.8162000179290771
# training accuracy after 186 epochs is 0.82792729139328
# test accuracy after 187 epochs is 0.8172000050544739
# training accuracy after 187 epochs is 0.827963650226593
# test accuracy after 188 epochs is 0.8166000247001648
# training accuracy after 188 epochs is 0.8282181620597839
# test accuracy after 189 epochs is 0.8174999952316284
# training accuracy after 189 epochs is 0.8282181620597839
# test accuracy after 190 epochs is 0.8174999952316284
# training accuracy after 190 epochs is 0.828181803226471
# test accuracy after 191 epochs is 0.8174999952316284
# training accuracy after 191 epochs is 0.8282363414764404
# test accuracy after 192 epochs is 0.8170999884605408
# training accuracy after 192 epochs is 0.8280545473098755
# test accuracy after 193 epochs is 0.8172000050544739
# training accuracy after 193 epochs is 0.8278727531433105
# test accuracy after 194 epochs is 0.816100001335144
# training accuracy after 194 epochs is 0.8285090923309326
# test accuracy after 195 epochs is 0.8167999982833862
# training accuracy after 195 epochs is 0.8285090923309326
# test accuracy after 196 epochs is 0.8177000284194946
# training accuracy after 196 epochs is 0.828181803226471
# test accuracy after 197 epochs is 0.8172000050544739
# training accuracy after 197 epochs is 0.8283818364143372
# test accuracy after 198 epochs is 0.8177000284194946
# training accuracy after 198 epochs is 0.8286363482475281
# test accuracy after 199 epochs is 0.8169999718666077
# training accuracy after 199 epochs is 0.8285636305809021
# test accuracy after 200 epochs is 0.8180999755859375

# %%
#train acc


input_data = train.images 
label_value=train.labels
preds = tf.nn.softmax(prediction(input_data))
correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
accuracy
