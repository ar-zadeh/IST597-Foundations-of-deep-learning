# %%
""" 
author:-aam35

"""
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import numpy as np
import tensorflow as tf
tf.enable_eager_execution()
import time
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import tensorflow.contrib.eager as tfe




tf.executing_eagerly()
# Define paramaters for the model
learning_rate = 0.001
batch_size = 100
n_epochs = 20
n_train = 55000
n_test = 10000

# %%
from tensorflow.examples.tutorials.mnist import input_data
train, val, test = input_data.read_data_sets('data/fashion', source_url='http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/',one_hot=True,)
# Out:
# WARNING:tensorflow:From <ipython-input-3-0b106b6b18aa>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 26421880 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 29515 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/fashion/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 4422102 bytes.
# Extracting data/fashion/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 5148 bytes.
# Extracting data/fashion/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
w = tf.Variable(tf.random_normal([train.images.shape[1],train.labels.shape[1]],stddev=0.01))
b = tf.Variable(tf.zeros([1 , train.labels.shape[1]],dtype=tf.float32))

# %%
def model(x):
  logits = tf.matmul(x,w) + b
  return logits

# %%
#evaluate the loss

variables=[w,b]
def loss(model, img, label):
  prediction = model(img)
  return tf.losses.softmax_cross_entropy(label, logits=prediction)

#record the gradient with respect to the model variables 
def grad(model, img, label):
  with tf.GradientTape() as tape:
    loss_value = loss(model, img, label)
  return tape.gradient(loss_value, variables)

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
n_batch=train.images.shape[0]//batch_size

# %%
for i in range(n_epochs):
  for j in range(n_batch):
    img , label=train.next_batch(batch_size= batch_size)
    grads=grad(model,img,label)
    optimizer.apply_gradients(zip(grads,variables),global_step=tf.train.get_or_create_global_step())
  #train acc
  input_data = train.images 
  label_value=train.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'training accuracy after {i} epochs is {accuracy}')
  #test acc
  input_data = test.images 
  label_value=test.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'test accuracy after {i+1} epochs is {accuracy}')
# Out:
# training accuracy after 0 epochs is 0.8218727111816406
# test accuracy after 1 epochs is 0.8075000047683716
# training accuracy after 1 epochs is 0.8299636244773865
# test accuracy after 2 epochs is 0.8202999830245972
# training accuracy after 2 epochs is 0.8472181558609009
# test accuracy after 3 epochs is 0.83160001039505
# training accuracy after 3 epochs is 0.8518000245094299
# test accuracy after 4 epochs is 0.8367999792098999
# training accuracy after 4 epochs is 0.856218159198761
# test accuracy after 5 epochs is 0.8402000069618225
# training accuracy after 5 epochs is 0.8593090772628784
# test accuracy after 6 epochs is 0.839900016784668
# training accuracy after 6 epochs is 0.8601636290550232
# test accuracy after 7 epochs is 0.8438000082969666
# training accuracy after 7 epochs is 0.8566727042198181
# test accuracy after 8 epochs is 0.8422999978065491
# training accuracy after 8 epochs is 0.8605272769927979
# test accuracy after 9 epochs is 0.8418999910354614
# training accuracy after 9 epochs is 0.8638545274734497
# test accuracy after 10 epochs is 0.8457000255584717
# training accuracy after 10 epochs is 0.8630909323692322
# test accuracy after 11 epochs is 0.8424999713897705
# training accuracy after 11 epochs is 0.8641454577445984
# test accuracy after 12 epochs is 0.8440999984741211
# training accuracy after 12 epochs is 0.8603636622428894
# test accuracy after 13 epochs is 0.8428999781608582
# training accuracy after 13 epochs is 0.8692181706428528
# test accuracy after 14 epochs is 0.8464999794960022
# training accuracy after 14 epochs is 0.8659818172454834
# test accuracy after 15 epochs is 0.8445000052452087
# training accuracy after 15 epochs is 0.8679999709129333
# test accuracy after 16 epochs is 0.8447999954223633
# training accuracy after 16 epochs is 0.8666181564331055
# test accuracy after 17 epochs is 0.845300018787384
# training accuracy after 17 epochs is 0.8681091070175171
# test accuracy after 18 epochs is 0.8458999991416931
# training accuracy after 18 epochs is 0.8700000047683716
# test accuracy after 19 epochs is 0.8447999954223633
# training accuracy after 19 epochs is 0.8699272871017456
# test accuracy after 20 epochs is 0.8447999954223633

# %%
# For bigger batch size
batch_size = 200
n_batch=train.images.shape[0]//batch_size
for i in range(n_epochs):
  for j in range(n_batch):
    img , label=train.next_batch(batch_size= batch_size)
    grads=grad(model,img,label)
    optimizer.apply_gradients(zip(grads,variables),global_step=tf.train.get_or_create_global_step())
  #train acc
  input_data = train.images 
  label_value=train.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'training accuracy after {i} epochs is {accuracy}')
  #test acc
  input_data = test.images 
  label_value=test.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'test accuracy after {i+1} epochs is {accuracy}')
# Out:
# training accuracy after 0 epochs is 0.8713818192481995
# test accuracy after 1 epochs is 0.8454999923706055
# training accuracy after 1 epochs is 0.8713454604148865
# test accuracy after 2 epochs is 0.8467000126838684
# training accuracy after 2 epochs is 0.8679817914962769
# test accuracy after 3 epochs is 0.8454999923706055
# training accuracy after 3 epochs is 0.869381844997406
# test accuracy after 4 epochs is 0.8454999923706055
# training accuracy after 4 epochs is 0.8707636594772339
# test accuracy after 5 epochs is 0.8478000164031982
# training accuracy after 5 epochs is 0.8690727353096008
# test accuracy after 6 epochs is 0.8440999984741211
# training accuracy after 6 epochs is 0.8708000183105469
# test accuracy after 7 epochs is 0.8460000157356262
# training accuracy after 7 epochs is 0.8712000250816345
# test accuracy after 8 epochs is 0.8460000157356262
# training accuracy after 8 epochs is 0.8713818192481995
# test accuracy after 9 epochs is 0.8446000218391418
# training accuracy after 9 epochs is 0.8707454800605774
# test accuracy after 10 epochs is 0.8464000225067139
# training accuracy after 10 epochs is 0.8723272681236267
# test accuracy after 11 epochs is 0.8458999991416931
# training accuracy after 11 epochs is 0.8727818131446838
# test accuracy after 12 epochs is 0.8475000262260437
# training accuracy after 12 epochs is 0.8720909357070923
# test accuracy after 13 epochs is 0.8450000286102295
# training accuracy after 13 epochs is 0.873163640499115
# test accuracy after 14 epochs is 0.847100019454956
# training accuracy after 14 epochs is 0.8726363778114319
# test accuracy after 15 epochs is 0.8463000059127808
# training accuracy after 15 epochs is 0.8723272681236267
# test accuracy after 16 epochs is 0.845300018787384
# training accuracy after 16 epochs is 0.8717636466026306
# test accuracy after 17 epochs is 0.8447999954223633
# training accuracy after 17 epochs is 0.8722545504570007
# test accuracy after 18 epochs is 0.8456000089645386
# training accuracy after 18 epochs is 0.8721454739570618
# test accuracy after 19 epochs is 0.8450999855995178
# training accuracy after 19 epochs is 0.8746727108955383
# test accuracy after 20 epochs is 0.8454999923706055

# %%
# For way smaller batch size
batch_size = 10
n_batch=train.images.shape[0]//batch_size
for i in range(n_epochs):
  for j in range(n_batch):
    img , label=train.next_batch(batch_size= batch_size)
    grads=grad(model,img,label)
    optimizer.apply_gradients(zip(grads,variables),global_step=tf.train.get_or_create_global_step())
  #train acc
  input_data = train.images 
  label_value=train.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'training accuracy after {i} epochs is {accuracy}')
  #test acc
  input_data = test.images 
  label_value=test.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'test accuracy after {i+1} epochs is {accuracy}')
# Out:
# training accuracy after 0 epochs is 0.8608909249305725
# test accuracy after 1 epochs is 0.8363999724388123
# training accuracy after 1 epochs is 0.8696727156639099
# test accuracy after 2 epochs is 0.84170001745224
# training accuracy after 2 epochs is 0.8672000169754028
# test accuracy after 3 epochs is 0.8409000039100647
# training accuracy after 3 epochs is 0.8673454523086548
# test accuracy after 4 epochs is 0.8416000008583069
# training accuracy after 4 epochs is 0.8701817989349365
# test accuracy after 5 epochs is 0.8442000150680542
# training accuracy after 5 epochs is 0.8686545491218567
# test accuracy after 6 epochs is 0.840499997138977
# training accuracy after 6 epochs is 0.8678727149963379
# test accuracy after 7 epochs is 0.8367999792098999
# training accuracy after 7 epochs is 0.873127281665802
# test accuracy after 8 epochs is 0.8431000113487244
# training accuracy after 8 epochs is 0.8704181909561157
# test accuracy after 9 epochs is 0.8421000242233276
# training accuracy after 9 epochs is 0.875
# test accuracy after 10 epochs is 0.8434000015258789
# training accuracy after 10 epochs is 0.8723090887069702
# test accuracy after 11 epochs is 0.8411999940872192
# training accuracy after 11 epochs is 0.8535454273223877
# test accuracy after 12 epochs is 0.8237000107765198
# training accuracy after 12 epochs is 0.8718000054359436
# test accuracy after 13 epochs is 0.8410000205039978
# training accuracy after 13 epochs is 0.8705090880393982
# test accuracy after 14 epochs is 0.840399980545044
# training accuracy after 14 epochs is 0.8695818185806274
# test accuracy after 15 epochs is 0.8375999927520752
# training accuracy after 15 epochs is 0.8752727508544922
# test accuracy after 16 epochs is 0.8427000045776367
# training accuracy after 16 epochs is 0.8721454739570618
# test accuracy after 17 epochs is 0.8393999934196472
# training accuracy after 17 epochs is 0.8677454590797424
# test accuracy after 18 epochs is 0.8377000093460083
# training accuracy after 18 epochs is 0.8734363913536072
# test accuracy after 19 epochs is 0.8395000100135803
# training accuracy after 19 epochs is 0.8741272687911987
# test accuracy after 20 epochs is 0.8398000001907349

# %%
#test acc

input_data = test.images 
label_value=test.labels
preds = tf.nn.softmax(model(input_data))
correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
accuracy

# %%
#Step 10: Helper function to plot images in 3*3 grid
#You can change the function based on your input pipeline

img_shape = [28,28]


def plot_images(images, y, yhat=None):
    assert len(images) == len(y) == 9
    


    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_shape), cmap='binary')

        # Show true and predicted classes.
        if yhat is None:
            xlabel = "True: {0}".format(y[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(y[i], yhat[i])

        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()

#Get image from test set 
images = test.images[0:9]

# Get the true classes for those images.
y = test.labels[0:9]

# Plot the images and labels using our helper-function above.
plot_images(images=images, y=y)


#Second plot weights 
def plot_weights(w):
    # Get the values for the weights from the TensorFlow variable.
    #TO DO ####
    # Get the lowest and highest values for the weights.
    # This is used to correct the colour intensity across
    # the images so they can be compared with each other.
    w_min =-2.248271
    #TO DO## obtains these value from W
    w_max = 1.6520177

    # Create figure with 3x4 sub-plots,
    # where the last 2 sub-plots are unused.
    fig, axes = plt.subplots(3, 4)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Only use the weights for the first 10 sub-plots.
        if i<10:
            # Get the weights for the i'th digit and reshape it.
            # Note that w.shape == (img_size_flat, 10)
            image = w[:, i].reshape(img_shape)

            # Set the label for the sub-plot.
            ax.set_xlabel("Weights: {0}".format(i))

            # Plot the image.
            ax.imshow(image, vmin=w_min, vmax=w_max, cmap='seismic')

        # Remove ticks from each sub-plot.
        ax.set_xticks([])
        ax.set_yticks([])
        
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()


plot_weights(w.numpy())

# %%
weight = w
weight = weight.numpy()
from sklearn.cluster import KMeans
fig, axes = plt.subplots(3, 4)
fig.subplots_adjust(hspace=0.3, wspace=0.3)
for i, ax in enumerate(axes.flat):
    if i<10:
        a = weight[:,i]
        a = a.reshape(-1, 1)
        kmean = KMeans(n_clusters=2, random_state=0).fit(a)
        W = list()
        for j in kmean.labels_:
            if j == 1:
                W.append(255)
            else:
                W.append(0)
        W = np.asarray(W)
        print(f'for class{i+1}')
        ax.imshow(W.reshape(28,28))
plt.show()
fig, axes = plt.subplots(3, 4)
fig.subplots_adjust(hspace=0.3, wspace=0.3)
for i, ax in enumerate(axes.flat):
    if i<10:
        a = weight[:,i]
        a = a.reshape(-1, 1)
        kmean = KMeans(n_clusters=3, random_state=0).fit(a)
        W = list()
        for j in kmean.labels_:
            if j == 1:
                W.append(255)
            elif j == 2:
                W.append(128)
            else:
                W.append(0)
        W = np.asarray(W)
        print(f'for class{i+1}')
        ax.imshow(W.reshape(28,28))
plt.show()
