# %%
""" 
author:-aam35

"""
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

import numpy as np
import tensorflow as tf
tf.enable_eager_execution()
import time
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import tensorflow.contrib.eager as tfe




tf.executing_eagerly()
# Define paramaters for the model
learning_rate = 0.001
batch_size = 20
n_epochs = 20
n_train = 55000
n_test = 10000

# %%
from tensorflow.examples.tutorials.mnist import input_data
train, val, test = input_data.read_data_sets('data/fashion', source_url='http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/',one_hot=True,validation_size=1000)
# Out:
# Extracting data/fashion/train-images-idx3-ubyte.gz
# Extracting data/fashion/train-labels-idx1-ubyte.gz
# Extracting data/fashion/t10k-images-idx3-ubyte.gz
# Extracting data/fashion/t10k-labels-idx1-ubyte.gz

# %%
w = tf.Variable(tf.random_normal([train.images.shape[1],train.labels.shape[1]],stddev=0.01))
b = tf.Variable(tf.zeros([1 , train.labels.shape[1]],dtype=tf.float32))

# %%
def model(x):
  logits = tf.matmul(x,w) + b
  return logits

# %%
#evaluate the loss

variables=[w,b]
def loss(model, img, label):
  prediction = model(img)
  return tf.losses.softmax_cross_entropy(label, logits=prediction)

#record the gradient with respect to the model variables 
def grad(model, img, label):
  with tf.GradientTape() as tape:
    loss_value = loss(model, img, label)
  return tape.gradient(loss_value, variables)

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
n_batch=train.images.shape[0]//batch_size

# %%
for i in range(n_epochs):
  for j in range(n_batch):
    img , label=train.next_batch(batch_size= batch_size)
    grads=grad(model,img,label)
    optimizer.apply_gradients(zip(grads,variables),global_step=tf.train.get_or_create_global_step())
  #train acc
  input_data = train.images 
  label_value=train.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'training accuracy after {i} epochs is {accuracy}')
  #test acc
  input_data = test.images 
  label_value=test.labels
  preds = tf.nn.softmax(model(input_data))
  correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(label_value, 1))
  accuracy = tf.reduce_mean(tf.cast(correct_preds, tf.float32))
  print(f'test accuracy after {i+1} epochs is {accuracy}')
# Out:
# training accuracy after 0 epochs is 0.8239830732345581
# test accuracy after 1 epochs is 0.8129000067710876
# training accuracy after 1 epochs is 0.8413729071617126
# test accuracy after 2 epochs is 0.8263999819755554
# training accuracy after 2 epochs is 0.8435593247413635
# test accuracy after 3 epochs is 0.8289999961853027
# training accuracy after 3 epochs is 0.8528982996940613
# test accuracy after 4 epochs is 0.8331999778747559
# training accuracy after 4 epochs is 0.8547627329826355
# test accuracy after 5 epochs is 0.8353999853134155
# training accuracy after 5 epochs is 0.8549830317497253
# test accuracy after 6 epochs is 0.8363999724388123
# training accuracy after 6 epochs is 0.8597457408905029
# test accuracy after 7 epochs is 0.8402000069618225
# training accuracy after 7 epochs is 0.8631017208099365
# test accuracy after 8 epochs is 0.84170001745224
# training accuracy after 8 epochs is 0.8631864190101624
# test accuracy after 9 epochs is 0.8406999707221985
# training accuracy after 9 epochs is 0.8658643960952759
# test accuracy after 10 epochs is 0.8449000120162964
# training accuracy after 10 epochs is 0.8652542233467102
# test accuracy after 11 epochs is 0.8450000286102295
# training accuracy after 11 epochs is 0.8666270971298218
# test accuracy after 12 epochs is 0.8436999917030334
# training accuracy after 12 epochs is 0.8623898029327393
# test accuracy after 13 epochs is 0.8452000021934509
# training accuracy after 13 epochs is 0.8693729043006897
# test accuracy after 14 epochs is 0.8471999764442444
# training accuracy after 14 epochs is 0.8656610250473022
# test accuracy after 15 epochs is 0.8447999954223633
# training accuracy after 15 epochs is 0.8689152598381042
# test accuracy after 16 epochs is 0.8479999899864197
# training accuracy after 16 epochs is 0.8670847415924072
# test accuracy after 17 epochs is 0.8431000113487244
# training accuracy after 17 epochs is 0.8690000176429749
# test accuracy after 18 epochs is 0.8464000225067139
# training accuracy after 18 epochs is 0.8708305358886719
# test accuracy after 19 epochs is 0.845300018787384
# training accuracy after 19 epochs is 0.8618983030319214
# test accuracy after 20 epochs is 0.8384000062942505
# training accuracy after 20 epochs is 0.870457649230957
# test accuracy after 21 epochs is 0.847599983215332
# training accuracy after 21 epochs is 0.8724915385246277
# test accuracy after 22 epochs is 0.848800003528595
# training accuracy after 22 epochs is 0.8701695203781128
# test accuracy after 23 epochs is 0.8465999960899353
# training accuracy after 23 epochs is 0.8715084791183472
# test accuracy after 24 epochs is 0.8485999703407288
# training accuracy after 24 epochs is 0.8678644299507141
# test accuracy after 25 epochs is 0.8439000248908997
# training accuracy after 25 epochs is 0.8693050742149353
# test accuracy after 26 epochs is 0.8432999849319458
# training accuracy after 26 epochs is 0.8706949353218079
# test accuracy after 27 epochs is 0.8450999855995178
# training accuracy after 27 epochs is 0.8657966256141663
# test accuracy after 28 epochs is 0.8421000242233276
# training accuracy after 28 epochs is 0.8686779737472534
# test accuracy after 29 epochs is 0.8442000150680542
# training accuracy after 29 epochs is 0.8701016902923584
# test accuracy after 30 epochs is 0.8453999757766724
# training accuracy after 30 epochs is 0.8692033886909485
# test accuracy after 31 epochs is 0.8468999862670898
# training accuracy after 31 epochs is 0.8735254406929016
# test accuracy after 32 epochs is 0.8465999960899353
# training accuracy after 32 epochs is 0.8717288374900818
# test accuracy after 33 epochs is 0.8457000255584717
# training accuracy after 33 epochs is 0.8742542266845703
# test accuracy after 34 epochs is 0.8468999862670898
# training accuracy after 34 epochs is 0.8722034096717834
# test accuracy after 35 epochs is 0.8442000150680542
# training accuracy after 35 epochs is 0.8725593090057373
# test accuracy after 36 epochs is 0.845300018787384
# training accuracy after 36 epochs is 0.8718135356903076
# test accuracy after 37 epochs is 0.8438000082969666
# training accuracy after 37 epochs is 0.8718982934951782
# test accuracy after 38 epochs is 0.8435999751091003
# training accuracy after 38 epochs is 0.8750508427619934
# test accuracy after 39 epochs is 0.8464000225067139
# training accuracy after 39 epochs is 0.8750339150428772
# test accuracy after 40 epochs is 0.847000002861023
# training accuracy after 40 epochs is 0.8728813529014587
# test accuracy after 41 epochs is 0.8454999923706055
# training accuracy after 41 epochs is 0.8717626929283142
# test accuracy after 42 epochs is 0.8439000248908997
# training accuracy after 42 epochs is 0.8743389844894409
# test accuracy after 43 epochs is 0.8468000292778015
# training accuracy after 43 epochs is 0.873186469078064
# test accuracy after 44 epochs is 0.8443999886512756
# training accuracy after 44 epochs is 0.8750169277191162
# test accuracy after 45 epochs is 0.8478000164031982
# training accuracy after 45 epochs is 0.8742712140083313
# test accuracy after 46 epochs is 0.8450000286102295
# training accuracy after 46 epochs is 0.8728135824203491
# test accuracy after 47 epochs is 0.8450000286102295
# training accuracy after 47 epochs is 0.8749491572380066
# test accuracy after 48 epochs is 0.8442000150680542
# training accuracy after 48 epochs is 0.8733220100402832
# test accuracy after 49 epochs is 0.8420000076293945
# training accuracy after 49 epochs is 0.8741016983985901
# test accuracy after 50 epochs is 0.8454999923706055
# training accuracy after 50 epochs is 0.8745254278182983
# test accuracy after 51 epochs is 0.8440999984741211
# training accuracy after 51 epochs is 0.8746779561042786
# test accuracy after 52 epochs is 0.84579998254776
# training accuracy after 52 epochs is 0.8764745593070984
# test accuracy after 53 epochs is 0.8468000292778015
# training accuracy after 53 epochs is 0.8774067759513855
# test accuracy after 54 epochs is 0.8452000021934509
# training accuracy after 54 epochs is 0.8756101727485657
# test accuracy after 55 epochs is 0.8463000059127808
# training accuracy after 55 epochs is 0.8749152421951294
# test accuracy after 56 epochs is 0.8452000021934509
# training accuracy after 56 epochs is 0.8660339117050171
# test accuracy after 57 epochs is 0.8371000289916992
# training accuracy after 57 epochs is 0.8755084872245789
# test accuracy after 58 epochs is 0.8456000089645386
# training accuracy after 58 epochs is 0.876423716545105
# test accuracy after 59 epochs is 0.8464000225067139
# training accuracy after 59 epochs is 0.8770169615745544
# test accuracy after 60 epochs is 0.8464000225067139
# training accuracy after 60 epochs is 0.870593249797821
# test accuracy after 61 epochs is 0.8407999873161316
# training accuracy after 61 epochs is 0.874728798866272
# test accuracy after 62 epochs is 0.845300018787384
# training accuracy after 62 epochs is 0.876305103302002
# test accuracy after 63 epochs is 0.8457000255584717
# training accuracy after 63 epochs is 0.8741864562034607
# test accuracy after 64 epochs is 0.843500018119812
# training accuracy after 64 epochs is 0.8775084614753723
# test accuracy after 65 epochs is 0.8461999893188477
# training accuracy after 65 epochs is 0.8767288327217102
# test accuracy after 66 epochs is 0.8442000150680542
# training accuracy after 66 epochs is 0.8755254149436951
# test accuracy after 67 epochs is 0.8428999781608582
# training accuracy after 67 epochs is 0.8740339279174805
# test accuracy after 68 epochs is 0.843999981880188
# training accuracy after 68 epochs is 0.8744915127754211
# test accuracy after 69 epochs is 0.8446999788284302
# training accuracy after 69 epochs is 0.8781694769859314
# test accuracy after 70 epochs is 0.8445000052452087
# training accuracy after 70 epochs is 0.876423716545105
# test accuracy after 71 epochs is 0.8454999923706055
# training accuracy after 71 epochs is 0.8746271133422852
# test accuracy after 72 epochs is 0.842199981212616
# training accuracy after 72 epochs is 0.8763220310211182
# test accuracy after 73 epochs is 0.8453999757766724
# training accuracy after 73 epochs is 0.8773728609085083
# test accuracy after 74 epochs is 0.8449000120162964
# training accuracy after 74 epochs is 0.8770169615745544
# test accuracy after 75 epochs is 0.8446999788284302
# training accuracy after 75 epochs is 0.8773220181465149
# test accuracy after 76 epochs is 0.8452000021934509
# training accuracy after 76 epochs is 0.8769152760505676
# test accuracy after 77 epochs is 0.8458999991416931
# training accuracy after 77 epochs is 0.8736101984977722
# test accuracy after 78 epochs is 0.8424000144004822
# training accuracy after 78 epochs is 0.877101719379425
# test accuracy after 79 epochs is 0.8449000120162964
# training accuracy after 79 epochs is 0.8787118792533875
# test accuracy after 80 epochs is 0.8453999757766724
# training accuracy after 80 epochs is 0.8763728737831116
# test accuracy after 81 epochs is 0.8414000272750854
# training accuracy after 81 epochs is 0.8759152293205261
# test accuracy after 82 epochs is 0.8424999713897705
# training accuracy after 82 epochs is 0.8790339231491089
# test accuracy after 83 epochs is 0.8435999751091003
# training accuracy after 83 epochs is 0.8785593509674072
# test accuracy after 84 epochs is 0.8465999960899353
# training accuracy after 84 epochs is 0.8751864433288574
# test accuracy after 85 epochs is 0.843999981880188
# training accuracy after 85 epochs is 0.8757118582725525
# test accuracy after 86 epochs is 0.8429999947547913
# training accuracy after 86 epochs is 0.8771864175796509
# test accuracy after 87 epochs is 0.8418999910354614
# training accuracy after 87 epochs is 0.8745593428611755
# test accuracy after 88 epochs is 0.8410000205039978
# training accuracy after 88 epochs is 0.8775932192802429
# test accuracy after 89 epochs is 0.8442999720573425
# training accuracy after 89 epochs is 0.8776101469993591
# test accuracy after 90 epochs is 0.8443999886512756
# training accuracy after 90 epochs is 0.8784745931625366
# test accuracy after 91 epochs is 0.8461999893188477
# training accuracy after 91 epochs is 0.8778135776519775
# test accuracy after 92 epochs is 0.8456000089645386
# training accuracy after 92 epochs is 0.8785932064056396
# test accuracy after 93 epochs is 0.8449000120162964
# training accuracy after 93 epochs is 0.8798474669456482
# test accuracy after 94 epochs is 0.8467000126838684
# training accuracy after 94 epochs is 0.8757627010345459
# test accuracy after 95 epochs is 0.8395000100135803
# training accuracy after 95 epochs is 0.87784743309021
# test accuracy after 96 epochs is 0.8443999886512756
# training accuracy after 96 epochs is 0.8781864643096924
# test accuracy after 97 epochs is 0.8434000015258789
# training accuracy after 97 epochs is 0.877864420413971
# test accuracy after 98 epochs is 0.843500018119812
# training accuracy after 98 epochs is 0.8791864514350891
# test accuracy after 99 epochs is 0.8439000248908997
# training accuracy after 99 epochs is 0.8743559122085571
# test accuracy after 100 epochs is 0.842199981212616
